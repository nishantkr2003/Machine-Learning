# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import pandas as pd

# %%
dataset=pd.read_csv(r"Boston.csv")
dataset.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
dataset.shape
# Out:
# (506, 15)

# %%
input_data =dataset.iloc[:,:-1]
output_data=dataset["medv"]

# %%
input_data
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat
# 0    296     15.3  396.90   4.98
# 1    242     17.8  396.90   9.14
# 2    242     17.8  392.83   4.03
# 3    222     18.7  394.63   2.94
# 4    222     18.7  396.90   5.33
# ..   ...      ...     ...    ...
# 501  273     21.0  391.99   9.67
# 502  273     21.0  396.90   9.08
# 503  273     21.0  396.90   5.64
# 504  273     21.0  393.45   6.48
# 505  273     21.0  396.90   7.88
#
# [506 rows x 14 columns]

# %%
output_data
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(input_data,output_data,test_size=0.25)

# %%
x_test
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 344         345   0.03049  55.0   3.78     0  0.484  6.874   28.1  6.4654
# 360         361   4.54192   0.0  18.10     0  0.770  6.398   88.0  2.5182
# 96           97   0.11504   0.0   2.89     0  0.445  6.163   69.6  3.4952
# 412         413  18.81100   0.0  18.10     0  0.597  4.628  100.0  1.5539
# 79           80   0.08387   0.0  12.83     0  0.437  5.874   36.6  4.5026
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 119         120   0.14476   0.0  10.01     0  0.547  5.731   65.2  2.7592
# 16           17   1.05393   0.0   8.14     0  0.538  5.935   29.3  4.4986
# 465         466   3.16360   0.0  18.10     0  0.655  5.759   48.2  3.0665
# 311         312   0.79041   0.0   9.90     0  0.544  6.122   52.8  2.6403
# 194         195   0.01439  60.0   2.93     0  0.401  6.604   18.8  6.2196
#
#      rad  tax  ptratio   black  lstat
# 344    5  370     17.6  387.97   4.61
# 360   24  666     20.2  374.56   7.79
# 96     2  276     18.0  391.83  11.34
# 412   24  666     20.2   28.79  34.37
# 79     5  398     18.7  396.06   9.10
# ..   ...  ...      ...     ...    ...
# 119    6  432     17.8  391.50  13.61
# 16     4  307     21.0  386.85   6.58
# 465   24  666     20.2  334.40  14.13
# 311    4  304     18.4  396.90   5.98
# 194    1  265     15.6  376.70   4.38
#
# [127 rows x 14 columns]

# %%
x_train
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 335         336   0.03961   0.0   5.19     0  0.515  6.037   34.5  5.9853
# 26           27   0.67191   0.0   8.14     0  0.538  5.813   90.3  4.6820
# 460         461   4.81213   0.0  18.10     0  0.713  6.701   90.0  2.5975
# 491         492   0.10574   0.0  27.74     0  0.609  5.983   98.8  1.8681
# 187         188   0.07875  45.0   3.44     0  0.437  6.782   41.1  3.7886
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 286         287   0.01965  80.0   1.76     0  0.385  6.230   31.5  9.0892
# 274         275   0.05644  40.0   6.41     1  0.447  6.758   32.9  4.0776
# 505         506   0.04741   0.0  11.93     0  0.573  6.030   80.8  2.5050
# 261         262   0.53412  20.0   3.97     0  0.647  7.520   89.4  2.1398
# 410         411  51.13580   0.0  18.10     0  0.597  5.757  100.0  1.4130
#
#      rad  tax  ptratio   black  lstat
# 335    5  224     20.2  396.90   8.01
# 26     4  307     21.0  376.88  14.81
# 460   24  666     20.2  255.23  16.42
# 491    4  711     20.1  390.11  18.07
# 187    5  398     15.2  393.87   6.68
# ..   ...  ...      ...     ...    ...
# 286    1  241     18.2  341.60  12.93
# 274    4  254     17.6  396.90   3.53
# 505    1  273     21.0  396.90   7.88
# 261    5  264     13.0  388.37   7.26
# 410   24  666     20.2    2.60  10.11
#
# [379 rows x 14 columns]

# %%
y_train
# Out:
# 335    21.1
# 26     16.6
# 460    16.4
# 491    13.6
# 187    32.0
#        ...
# 286    20.1
# 274    32.4
# 505    11.9
# 261    43.1
# 410    15.0
# Name: medv, Length: 379, dtype: float64

# %%
y_test
# Out:
# 474    13.8
# 199    34.9
# 303    33.1
# 155    15.6
# 429     9.5
#        ...
# 157    41.3
# 121    20.3
# 420    16.7
# 408    17.2
# 413    16.3
# Name: medv, Length: 127, dtype: float64

# %%
x_test.shape,y_test.shape
# Out:
# ((127, 14), (127,))

# %%
x_train.shape,y_test.shape
# Out:
# ((379, 14), (127,))
